# %%
import pyreadr

# %%
result = pyreadr.read_r("camels-spat/SimArray.Rdata")
# Out:
# ---------------------------------------------------------------------------
# LibrdataError                             Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 result = pyreadr.read_r("camels-spat/SimArray.Rdata")
#
# File ~/virtual-envs/scienv/lib/python3.11/site-packages/pyreadr/pyreadr.py:66, in read_r(path, use_objects, timezone)
#      64 if not os.path.isfile(filename_bytes):
#      65     raise PyreadrError("File {0} does not exist!".format(filename_bytes))
# ---> 66 parser.parse(filename_bytes)
#      68 result = OrderedDict()
#      69 for table_index, table in enumerate(parser.table_data):
#
# File ~/virtual-envs/scienv/lib/python3.11/site-packages/pyreadr/librdata.pyx:149, in pyreadr.librdata.Parser.parse()
#
# File ~/virtual-envs/scienv/lib/python3.11/site-packages/pyreadr/librdata.pyx:178, in pyreadr.librdata.Parser.parse()
#
# LibrdataError: Unable to read from file
